# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

from sentence_transformers import SentenceTransformer

# %%
def get_meta(body, attr):
    soup = BeautifulSoup(body, parser='html.parser')
    metatags = soup.findAll('meta')
    attr_ = [m.get(attr, None) for m in metatags]
    attr = [a.lower() for a in attr_ if a != None]
    
    return np.unique(attr)

# %%
url = 'http://cnn.com'
body = requests.get(url).text
soup = BeautifulSoup(body, 'lxml')

# %%
soup.findAll('meta')
# Out:
# [<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>,
#  <meta charset="utf-8"/>,
#  <meta content="text/html" http-equiv="Content-Type"/>,
#  <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>,
#  <meta content="intl_homepage" name="section"/>,
#  <meta content="unsafe-url" name="referrer"/>,
#  <meta content="2014-02-24T14:45:54Z" property="og:pubdate"/>,
#  <meta content="2014-02-24T14:45:54Z" name="pubdate"/>,
#  <meta content="2020-12-14T14:53:12Z" name="lastmod"/>,
#  <meta content="https://edition.cnn.com" property="og:url"/>,
#  <meta content="CNN International - Breaking News, US News, World News and Video" property="og:title"/>,
#  <meta content="CNN International - Breaking News, US News, World News and Video" name="twitter:title"/>,
#  <meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." property="og:description"/>,
#  <meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." name="description"/>,
#  <meta content="Find the latest breaking news and information on the top stories, weather, business, entertainment, politics, and more. For in-depth coverage, CNN provides special reports, video, audio, photo galleries, and interactive guides." name="twitter:description"/>,
#  <meta content="breaking news, news online, U.S. news, world news, developing story, news video, CNN news, weather, business, money, politics, law, technology, entertainment, education, travel, health, special reports, autos, CNN TV" name="keywords"/>,
#  <meta content="CNN" property="og:site_name"/>,
#  <meta content="summary_large_image" name="twitter:card"/>,
#  <meta content="website" property="og:type"/>,
#  <meta content="https://edition.cnn.com" property="vr:canonical"/>,
#  <meta content="80401312489" property="fb:app_id"/>,
#  <meta content="5550296508,18793419640" property="fb:pages"/>]

# %%
df = pd.read_json('/dlabdata1/lugeon/websites_alexa_mostpop_html.json.gz', orient='records', lines=True)

# %%
df = df[(df.errcode==200) & (df.cat != 'World')]

# %%
df
# Out:
#      uid                    url  \
# 0      0     http://xvideos.com
# 1      1        http://xnxx.com
# 2      2  http://chaturbate.com
# 3      3     http://youporn.com
# 4      4  http://livejasmin.com
# ..   ...                    ...
# 795  795     http://arsenal.com
# 796  796     http://sherdog.com
# 797  797        http://hkjc.com
# 798  798      http://afl.com.au
# 799  799         http://nrl.com
#
#                                                   html  errcode     cat  \
# 0    <!doctype html>\n<html class="xv-responsive" l...    200.0   Adult
# 1    <!doctype html>\n<html class="xv-responsive" l...    200.0   Adult
# 2    <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...    200.0   Adult
# 3    <!DOCTYPE html>\n<html lang="en" class="grid">...    200.0   Adult
# 4    \n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0...    200.0   Adult
# ..                                                 ...      ...     ...
# 795  <!DOCTYPE html>\n<html lang="en" dir="ltr" pre...    200.0  Sports
# 796  <!DOCTYPE html><html version="XHTML+RDFa 1.0">...    200.0  Sports
# 797  \r\n<!DOCTYPE html>\r\n<html>\r\n\t<head>\r\n\...    200.0  Sports
# 798  <html lang="en">\n<head>\n\t<meta charset="UTF...    200.0  Sports
# 799  \r\n\r\n<!DOCTYPE html>\r\n<html lang="en" cla...    200.0  Sports
#
#                                              meta_name  \
# 0    [description, format-detection, keywords, rati...
# 1    [description, format-detection, keywords, rati...
# 2    [description, keywords, msapplication-tilecolo...
# 3    [adsbytrafficjunkycontext, application-name, d...
# 4    [category, description, google, issearchpage, ...
# ..                                                 ...
# 795  [apple-itunes-app, description, generator, goo...
# 796  [author, copyright, description, publisher, ro...
# 797                  [description, keywords, viewport]
# 798  [apple-itunes-app, apple-mobile-web-app-status...
# 799  [description, handheldfriendly, mobileoptimize...
#
#                                          meta_proprety
# 0                                                   []
# 1                                                   []
# 2    [og:description, og:image, og:image:height, og...
# 3                                                   []
# 4    [og:description, og:image, og:site_name, og:ti...
# ..                                                 ...
# 795                                                 []
# 796  [fb:admins, og:description, og:image, og:site_...
# 797                                                 []
# 798  [fb:app_id, fb:pages, og:description, og:image...
# 799  [fb:app_id, og:description, og:image, og:local...
#
# [715 rows x 7 columns]

# %%
df['meta_name'] = df.apply(lambda row: get_meta(row.html, 'name'), axis=1)

# %%
df['meta_proprety'] = df.apply(lambda row: get_meta(row.html, 'property'), axis=1)

# %%
df.head()
# Out:
#    uid                    url  \
# 0    0     http://xvideos.com
# 1    1        http://xnxx.com
# 2    2  http://chaturbate.com
# 3    3     http://youporn.com
# 4    4  http://livejasmin.com
#
#                                                 html  errcode    cat  \
# 0  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 1  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...    200.0  Adult
# 3  <!DOCTYPE html>\n<html lang="en" class="grid">...    200.0  Adult
# 4  \n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0...    200.0  Adult
#
#                                            meta_name  \
# 0  [description, format-detection, keywords, rati...
# 1  [description, format-detection, keywords, rati...
# 2  [description, keywords, msapplication-tilecolo...
# 3  [adsbytrafficjunkycontext, application-name, d...
# 4  [category, description, google, issearchpage, ...
#
#                                        meta_proprety
# 0                                                 []
# 1                                                 []
# 2  [og:description, og:image, og:image:height, og...
# 3                                                 []
# 4  [og:description, og:image, og:site_name, og:ti...

# %%
df.shape
# Out:
# (715, 7)

# %% [markdown]
# ## Values of attributes *name* and *proprety*, and their presence in the various categories

# %%
cats = df.cat.unique()

def compute_attr_presence(attr, min_pres):
    all_meta_attr = [] 

    counts = []

    for cat in cats:
        df_cat = df[df.cat == cat]
        meta_attrs = df_cat[attr].values
        count = pd.Series([a for b in meta_attrs for a in b]).value_counts() / df_cat.shape[0]
        min_count = count[count >= min_pres]
        counts.append(count)
        all_meta_attr += min_count.index.tolist()
        #print(cat)
        #print(count, '\n')

    all_meta_attr = np.unique(all_meta_attr)
    
    count_array = np.zeros((len(all_meta_attr), len(cats)))
    
    for i in range(len(cats)):
        j = 0
        for attr in all_meta_attr:
            count_array[j,i] = counts[i].get(attr, 0)
            j += 1
        
    return count_array, all_meta_attr

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

count_attr, attr_names = compute_attr_presence('meta_name', 0.3)

fig, ax = plt.subplots(figsize=(8, 12))

im = plt.imshow(count_attr, cmap='YlOrBr', interpolation='nearest', vmin=0, vmax=1)

plt.xticks(np.arange(len(cats)), cats, rotation=90, fontsize=15)
plt.yticks(np.arange(len(attr_names)), attr_names, fontsize=15)
ax.xaxis.tick_top()

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.3)

plt.colorbar(im, cax=cax)

#ax.title.set_text('Presence of the different kinds of "name" attribute w.r.t to categories')

plt.show()

# %%
count_attr, attr_names = compute_attr_presence('meta_name', 0.1)

std = []

for i in range(count_attr.shape[0]):
    std.append(np.std(count_attr[i]))
    
sorti = np.argsort(std)[::-1]

print('The presence-feature with the most variance are...')

for i in sorti[:15]:
    print("{:<18} {:.4f}".format(attr_names[i], std[i]))
# Out:
# The presence-feature with the most variance are...
# twitter:site       0.1288
# twitter:card       0.1177
# rating             0.0972
# apple-itunes-app   0.0970
# theme-color        0.0864
# keywords           0.0860
# twitter:title      0.0843
# viewport           0.0820
# twitter:image      0.0810
# robots             0.0776
# twitter:description 0.0767
# generator          0.0731
# description        0.0710
# application-name   0.0664
# format-detection   0.0663

# %%
most_variant_attr = attr_names[sorti][:15]
most_variant_attr
# Out:
# array(['twitter:site', 'twitter:card', 'rating', 'apple-itunes-app',
#        'theme-color', 'keywords', 'twitter:title', 'viewport',
#        'twitter:image', 'robots', 'twitter:description', 'generator',
#        'description', 'application-name', 'format-detection'],
#       dtype='<U37')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

count_attr, attr_names = compute_attr_presence('meta_proprety', 0.2)

fig, ax = plt.subplots(figsize=(8, 12))

im = plt.imshow(count_attr, cmap='YlOrBr', interpolation='nearest', vmin=0, vmax=1)

plt.xticks(np.arange(len(cats)), cats, rotation=90)
plt.yticks(np.arange(len(attr_names)), attr_names)
ax.xaxis.tick_top()

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.3)

plt.colorbar(im, cax=cax)

ax.title.set_text('Presence of the different kinds of "proprety" attribute w.r.t to categories')

plt.show()

# %% [markdown]
# ## Embedding of the *description*

# %%
def get_desc(body):
    soup = BeautifulSoup(body, 'html.parser')
    desc = soup.find('meta', attrs = {'name': ['description', 'Description']})
    if desc:
        return [s.strip() for s in desc["content"].split('.') if s]
    return None

# %%
get_desc(requests.get('http://facebook.com').text)
# Out:
# ['Erstelle ein Konto oder melde dich bei Facebook an',
#  'Verbinde dich mit Freunden, Familie und anderen Personen, die du kennst',
#  'Teile Fotos und Videos,']

# %%
df['desc'] = df.apply(lambda row: get_desc(row.html), axis=1)

# %%
model = SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')

# %%
def encode_or_none(s):
    if s == None:
        return None
    else:
        return model.encode(s).mean(axis=0)

# %%
df['desc_emb'] = df.apply(lambda row: encode_or_none(row.desc), axis=1)
# Out:
# <ipython-input-37-e1af19ed9cdc>:5: RuntimeWarning: Mean of empty slice.
#   return model.encode(s).mean(axis=0)
# /scratch/lugeon/basic-env/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df.head()
# Out:
#    uid                    url  \
# 0    0     http://xvideos.com
# 1    1        http://xnxx.com
# 2    2  http://chaturbate.com
# 3    3     http://youporn.com
# 4    4  http://livejasmin.com
#
#                                                 html  errcode    cat  \
# 0  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 1  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...    200.0  Adult
# 3  <!DOCTYPE html>\n<html lang="en" class="grid">...    200.0  Adult
# 4  \n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0...    200.0  Adult
#
#                                            meta_name  \
# 0  [description, format-detection, keywords, rati...
# 1  [description, format-detection, keywords, rati...
# 2  [description, keywords, msapplication-tilecolo...
# 3  [adsbytrafficjunkycontext, application-name, d...
# 4  [category, description, google, issearchpage, ...
#
#                                        meta_proprety  \
# 0                                                 []
# 1                                                 []
# 2  [og:description, og:image, og:image:height, og...
# 3                                                 []
# 4  [og:description, og:image, og:site_name, og:ti...
#
#                                                 desc  \
# 0                         [XVIDEOS Free Porn Videos]
# 1  [XNXX delivers free sex movies and fast free p...
# 2  [Watch Live Cams Now! No Registration Required...
# 3  [YouPorn is your home for free XXX porn videos...
# 4  [Chat for FREE on LiveJasmin and watch HD Live...
#
#                                             desc_emb
# 0  [-0.14601764, 0.14098579, 0.011557743, -0.4463...
# 1  [0.13418703, 0.043666907, -0.066224284, -0.204...
# 2  [-0.008984726, -0.014585882, -0.08052273, -0.4...
# 3  [-0.06611139, 0.007593561, -0.019413913, -0.20...
# 4  [0.03814076, -0.044238452, 0.09227037, -0.4134...

# %%
df_desc = df[df.desc_emb.notnull()]
df_desc.reset_index(inplace=True, drop=True)

# %%
x = np.concatenate(df_desc.desc_emb.to_numpy()).ravel()
x = x.reshape(-1, 768)
x.shape
# Out:
# (619, 768)

# %%
df_desc.desc_emb[:10]
# Out:
# 0    [-0.14601764, 0.14098579, 0.011557743, -0.4463...
# 1    [0.13418703, 0.043666907, -0.066224284, -0.204...
# 2    [-0.008984726, -0.014585882, -0.08052273, -0.4...
# 3    [-0.06611139, 0.007593561, -0.019413913, -0.20...
# 4    [0.03814076, -0.044238452, 0.09227037, -0.4134...
# 5    [0.11699873, -0.08313186, 0.2162176, -0.283925...
# 6    [0.008679722, -0.17944118, -0.054632418, -0.30...
# 7    [-0.06002807, 0.020701338, 0.16299929, -0.0874...
# 8    [0.026830917, 0.046504308, 0.003074117, -0.085...
# 9    [0.025326768, -0.13555245, -0.08824211, -0.264...
# Name: desc_emb, dtype: object

# %%
from sklearn.manifold import TSNE

x_tsne = TSNE(n_components=2, random_state=42).fit_transform(x)

categories = np.sort(df_desc.cat.unique())

colormap = plt.get_cmap('tab20')

opacity = 1
marker_size = 30
marker = 'o'

fig, ax = plt.subplots(figsize=(10, 7))

n = 0
ncat = len(categories)

for cat in categories:
    ix = df_desc[df_desc.cat == cat].index
    x_val = x_tsne[ix][:,0]
    y_val = x_tsne[ix][:,1]
    plt.scatter(x_val, y_val, color=colormap(n), marker=marker, s=marker_size, alpha=opacity, label=cat)
    
    n += 1

ax.set_xlim([-45,80])
#ax.set_ylim([0,1])

ax.set_xticks([], [])
ax.set_yticks([], [])
    
#plt.title('t-SNE decomposition of description content in meta tags')
plt.legend(markerscale=2, fontsize=13)
plt.plot();
# Out:
# <ipython-input-47-5e90b69b2abe>:29: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# <ipython-input-47-5e90b69b2abe>:30: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])

# %% [markdown]
# ## Embedding of the *keywords*

# %%
def get_kw(body):
    soup = BeautifulSoup(body, 'html.parser')
    kw = soup.find('meta', attrs = {'name': 'keywords'})
    if kw:
        try:
            return [kw["content"]]
        except KeyError:
            pass
    return None

# %%
get_kw(requests.get('http://foxnews.com').text)

# %%
df['kw'] = df.apply(lambda row: get_kw(row.html), axis=1)

# %%
df['kw_emb'] = df.apply(lambda row: encode_or_none(row.kw), axis=1)

# %%
df_kw = df[df.kw_emb.notnull()]
df_kw.reset_index(inplace=True, drop=True)

# %%
x = np.concatenate(df_kw.kw_emb.to_numpy()).ravel()
x = x.reshape(-1, 768)
x.shape
# Out:
# (264, 768)

# %%
x_tsne = TSNE(n_components=2, random_state=42).fit_transform(x)

categories = np.sort(df_desc.cat.unique())

colormap = plt.get_cmap('tab20')

opacity = 1
marker_size = 30
marker = 'o'

fig, ax = plt.subplots(figsize=(10, 7))

n = 0
ncat = len(categories)

for cat in categories:
    ix = df_kw[df_kw.cat == cat].index
    x_val = x_tsne[ix][:,0]
    y_val = x_tsne[ix][:,1]
    plt.scatter(x_val, y_val, color=colormap(n), marker=marker, s=marker_size, alpha=opacity, label=cat)
    
    n += 1

ax.set_xlim([-25,40])
#ax.set_ylim([0,1])
    
plt.title('t-SNE decomposition of keywords content in meta tags')
plt.legend(markerscale=2, fontsize=13)
plt.plot();

# %% [markdown]
# Almost clusters!

# %% [markdown]
# ## Inspecting time-related meta-name for News category

# %%
df_cat = df[df.cat == 'News']
meta_attrs = df_cat['meta_name'].values
count = pd.Series([a for b in meta_attrs for a in b]).value_counts()

# %%
target = ['last', 'pub', 'date', 'mod']

# %%
news_spec = np.unique([m for m in count.index for t in target if t in m]).tolist()
news_spec
# Out:
# ['date',
#  'dc.date',
#  'dc.date.created',
#  'dc.publisher',
#  'dcterms.datecopyrighted',
#  'dcterms.modified',
#  'last-modified',
#  'last-modified-date',
#  'last-modified-time',
#  'lastmod',
#  'minutely-publisher',
#  'msvalidate.01',
#  'pubdate',
#  'publisher']

# %%
news_date_spec = ['dc.date.created',
'dc.publisher',
 'last-modified',
 'last-modified-date',
 'last-modified-time',
 'lastmod',
 'minutely-publisher',
 'msvalidate.01',
 'pubdate',
 'publisher']

# removed two terms with dcterms.blablalba...

# %%
cats = df.cat.unique()

v = []

for cat in cats:
    df_cat = df[df.cat == cat]
    mask = [len(set(news_date_spec).intersection(set(m.tolist()))) > 0 for m in df_cat.meta_name]
    v.append(sum(mask) / df_cat.shape[0])
    
np.std(v)
# Out:
# 0.008725923088644574

# %%
mask = [len(set(news_date_spec).intersection(set(m.tolist()))) > 0 for m in df.meta_name]
df[mask].cat.value_counts()
# Out:
# Arts    1
# Home    1
# News    1
# Name: cat, dtype: int64

# %% [markdown]
# The standard deviation of the grouped "time-related attributes" indicates that this also could be a valid feature

# %% [markdown]
# ## Putting everything together

# %%
df_agg = df[df.desc_emb.notnull()]

# %%
def add_or_none(row):
    if type(row.kw_emb) == np.ndarray:
        return row.desc_emb + row.kw_emb
    else:
        return row.desc_emb

# %%
df_agg['kw_desc_emb'] = df_agg.apply(add_or_none, axis=1)
# Out:
# <ipython-input-43-9a40c5279969>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agg['kw_desc_emb'] = df_agg.apply(add_or_none, axis=1)

# %%
df_agg.head()
# Out:
#    uid                    url  \
# 0    0     http://xvideos.com
# 1    1        http://xnxx.com
# 2    2  http://chaturbate.com
# 3    3     http://youporn.com
# 4    4  http://livejasmin.com
#
#                                                 html  errcode    cat  \
# 0  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 1  <!doctype html>\n<html class="xv-responsive" l...    200.0  Adult
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...    200.0  Adult
# 3  <!DOCTYPE html>\n<html lang="en" class="grid">...    200.0  Adult
# 4  \n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0...    200.0  Adult
#
#                                            meta_name  \
# 0  [description, format-detection, keywords, rati...
# 1  [description, format-detection, keywords, rati...
# 2  [description, keywords, msapplication-tilecolo...
# 3  [adsbytrafficjunkycontext, application-name, d...
# 4  [category, description, google, issearchpage, ...
#
#                                        meta_proprety  \
# 0                                                 []
# 1                                                 []
# 2  [og:description, og:image, og:image:height, og...
# 3                                                 []
# 4  [og:description, og:image, og:site_name, og:ti...
#
#                                                 desc  \
# 0                         [XVIDEOS Free Porn Videos]
# 1  [XNXX delivers free sex movies and fast free p...
# 2  [Watch Live Cams Now! No Registration Required...
# 3  [YouPorn is your home for free XXX porn videos...
# 4  [Chat for FREE on LiveJasmin and watch HD Live...
#
#                                             desc_emb  \
# 0  [-0.14601764, 0.14098579, 0.011557743, -0.4463...
# 1  [0.13418701, 0.0436669, -0.066224284, -0.20475...
# 2  [-0.008984722, -0.01458589, -0.08052273, -0.43...
# 3  [-0.06611139, 0.007593561, -0.019413913, -0.20...
# 4  [0.038140766, -0.04423845, 0.092270374, -0.413...
#
#                                                   kw  \
# 0  [xvideos,xvideos.com, x videos,x video,porn,vi...
# 1  [porn,porn movies,free porn,free porn movies,s...
# 2  [free cams, free adult video chat, free sex we...
# 3                                               None
# 4  [live, gender, cams, cam, real, web, amateur, ...
#
#                                               kw_emb  \
# 0  [-0.05813962, 0.21787325, 0.015402947, -0.0584...
# 1  [-0.123688996, 0.20752415, -0.0052011064, -0.2...
# 2  [-0.122137934, 0.18165682, 0.05366501, -0.4386...
# 3                                               None
# 4  [-0.027970636, 0.02459159, 0.011430742, -0.245...
#
#                                          kw_desc_emb
# 0  [-0.20415726, 0.35885903, 0.02696069, -0.50479...
# 1  [0.010498017, 0.25119105, -0.07142539, -0.4737...
# 2  [-0.13112265, 0.16707093, -0.026857723, -0.868...
# 3  [-0.06611139, 0.007593561, -0.019413913, -0.20...
# 4  [0.01017013, -0.019646859, 0.103701115, -0.658...

# %%
df_agg['meta_name_emb'] = df_agg.apply(lambda row: [int(a in row.meta_name) for a in most_variant_attr], axis=1)
# Out:
# <ipython-input-45-32de4838deb1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agg['meta_name_emb'] = df_agg.apply(lambda row: [int(a in row.meta_name) for a in most_variant_attr], axis=1)

# %%
df_agg['time_attr_emb'] = df_agg.apply(lambda row: int(len([a for n in news_date_spec for a in row['meta_name'] if a == n]) > 0) , axis=1)
# Out:
# <ipython-input-46-f0ec46c53d4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agg['time_attr_emb'] = df_agg.apply(lambda row: int(len([a for n in news_date_spec for a in row['meta_name'] if a == n]) > 0) , axis=1)

# %%
df_agg['full_name_emb'] = df_agg.apply(lambda row: row.meta_name_emb + [row.time_attr_emb], axis=1)
# Out:
# <ipython-input-47-8d1363ecf05a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agg['full_name_emb'] = df_agg.apply(lambda row: row.meta_name_emb + [row.time_attr_emb], axis=1)

# %%
df_agg.head(1)
# Out:
#    uid                 url                                               html  \
# 0    0  http://xvideos.com  <!doctype html>\n<html class="xv-responsive" l...
#
#    errcode    cat                                          meta_name  \
# 0    200.0  Adult  [description, format-detection, keywords, rati...
#
#   meta_proprety                        desc  \
# 0            []  [XVIDEOS Free Porn Videos]
#
#                                             desc_emb  \
# 0  [-0.14601764, 0.14098579, 0.011557743, -0.4463...
#
#                                                   kw  \
# 0  [xvideos,xvideos.com, x videos,x video,porn,vi...
#
#                                               kw_emb  \
# 0  [-0.05813962, 0.21787325, 0.015402947, -0.0584...
#
#                                          kw_desc_emb  \
# 0  [-0.20415726, 0.35885903, 0.02696069, -0.50479...
#
#                                    meta_name_emb  time_attr_emb  \
# 0  [0, 0, 1, 0, 1, 1, 0, 1, 0, 0, 0, 0, 1, 0, 1]              0
#
#                                       full_name_emb
# 0  [0, 0, 1, 0, 1, 1, 0, 1, 0, 0, 0, 0, 1, 0, 1, 0]

# %%
df_agg.reset_index(inplace=True, drop=True)
x = np.concatenate(df_agg.kw_desc_emb.to_numpy()).ravel()
x = x.reshape(-1, 768)

x_tsne = TSNE(n_components=2, random_state=42).fit_transform(x)

categories = df_desc.cat.unique()

colormap = plt.get_cmap('tab20')

opacity = 1
marker_size = 30
marker = 'o'

fig, ax = plt.subplots(figsize=(14, 8))

n = 0
ncat = len(categories)

for cat in categories:
    ix = df_agg[df_agg.cat == cat].index
    x_val = x_tsne[ix][:,0]
    y_val = x_tsne[ix][:,1]
    plt.scatter(x_val, y_val, color=colormap(n), marker=marker, s=marker_size, alpha=opacity, label=cat)
    
    n += 1

ax.set_xlim([-55,40])
#ax.set_ylim([0,1])

plt.title('t-SNE decomposition of keywords content in meta tags')
plt.legend(markerscale=2)
plt.plot();

# %% [markdown]
# Adding the keywords to the description doesn't really improve the clusters, the information in the keywords may be redondant with the information already in the description (e.g same words)

# %%
from sklearn.preprocessing import normalize

x_desc = np.concatenate(df_agg.desc_emb.to_numpy()).ravel().reshape(-1, 768)

x_names = np.concatenate(df_agg.full_name_emb.to_numpy()).ravel().reshape(-1, 16)

x_full = np.concatenate((x_desc, x_names), axis=1)
x_full_norm = normalize(x_full, axis=0)

x_tsne = TSNE(n_components=2, random_state=42).fit_transform(x_full_norm)

categories = df_agg.cat.unique()

colormap = plt.get_cmap('tab20')

opacity = 1
marker_size = 30
marker = 'o'

fig, ax = plt.subplots(figsize=(12, 8))

n = 0
ncat = len(categories)

for cat in categories:
    ix = df_agg[df_agg.cat == cat].index
    x_val = x_tsne[ix][:,0]
    y_val = x_tsne[ix][:,1]
    plt.scatter(x_val, y_val, color=colormap(n), marker=marker, s=marker_size, alpha=opacity, label=cat)
    
    n += 1

ax.set_xlim([-45,60])
#ax.set_ylim([0,1])
    
plt.title('t-SNE decomposition of description + meta-names presence')
plt.legend(markerscale=2)
plt.plot();

# %% [markdown]
# As if clusters were more reconizable, but hard to tell

# %%
df[df.cat == 'News']
# Out:
#      uid                                  url  \
# 301  401                       http://cnn.com
# 302  402               http://news.google.com
# 303  403                   http://nytimes.com
# 304  404                http://indiatimes.com
# 305  405              http://shutterstock.com
# 306  406               http://theguardian.com
# 307  407            http://washingtonpost.com
# 308  408                http://news.yahoo.com
# 309  409                   http://foxnews.com
# 310  410                   http://weather.com
# 311  411   http://timesofindia.indiatimes.com
# 312  412                    http://forbes.com
# 313  413                      http://cnbc.com
# 314  414  http://economictimes.indiatimes.com
# 315  415                   http://reuters.com
# 316  416                 http://bloomberg.com
# 318  418                  http://usatoday.com
# 319  419                    http://nypost.com
# 322  422                     http://chron.com
# 323  423             http://indianexpress.com
# 325  425                        http://dw.com
# 326  426                   http://nbcnews.com
# 327  427                   http://news.com.au
# 328  428              http://drudgereport.com
# 329  429                    http://sfgate.com
# 330  430                   http://cbsnews.com
# 331  431              http://wunderground.com
# 332  432                   http://weather.gov
# 333  433                  http://thehindu.com
# 334  434                   http://thehill.com
# 336  436                 http://aljazeera.com
# 337  437                      http://time.com
# 338  438             http://thedailybeast.com
# 339  439               http://theatlantic.com
# 340  440                  http://livemint.com
# 341  441                http://abcnews.go.com
# 342  442                 http://newsnow.co.uk
# 343  443                       http://irna.ir
# 344  444                  http://bankrate.com
# 345  445                         http://yr.no
# 346  446                     http://patch.com
# 347  447                   http://variety.com
# 348  448                  http://euronews.com
#
#                                                   html  errcode   cat  \
# 301  <!DOCTYPE html><html class="no-js"><head><meta...    200.0  News
# 302  <!doctype html><html lang="en" dir="ltr"><head...    200.0  News
# 303  <!DOCTYPE html>\n<html lang="en"  xmlns:og="ht...    200.0  News
# 304  <!doctype html><html lang="en"><head><title da...    200.0  News
# 305  <!DOCTYPE html><html lang="en" class="no-js" d...    200.0  News
# 306  \n<!DOCTYPE html>\n<html id="js-context" class...    200.0  News
# 307  <!DOCTYPE html><html lang="en"><head><meta htt...    200.0  News
# 308  <!DOCTYPE html><html id="atomic" class="NoJs d...    200.0  News
# 309  <!DOCTYPE html><html lang="en"><head><meta cha...    200.0  News
# 310  <!doctype html><html dir="ltr" lang="de-CH"><h...    200.0  News
# 311  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//...    200.0  News
# 312  <!DOCTYPE html><html lang="en"><head><link rel...    200.0  News
# 313  <!DOCTYPE html><html lang="en" prefix="og=http...    200.0  News
# 314  <!DOCTYPE html><html><head><META http-equiv="C...    200.0  News
# 315  <!--[if !IE]> App Server /produs--i-090ba3b68a...    200.0  News
# 316  <!doctype html>\n<html>\n<head>\n    <title>Bl...    200.0  News
# 318  <!doctype html><html lang=en><head><meta chars...    200.0  News
# 319  <!DOCTYPE html>\n<html lang="en-US" class="no-...    200.0  News
# 322  \n\n\n                    \n<!doctype html>\n<...    200.0  News
# 323  <!DOCTYPE html>\n<html lang="en" xmlns:og="htt...    200.0  News
# 325  <!DOCTYPE html>\n<!--[if lt IE 7 ]><!-->\n<htm...    200.0  News
# 326  <!DOCTYPE html><html lang="en"><head><link hre...    200.0  News
# 327  \n<!doctype html>\n<html lang="en">\n\n\t\t\t\...    200.0  News
# 328  <html>\r\n<head>\r\n<title>DRUDGE REPORT 2021&...    200.0  News
# 329  \n\n\n                    \n<!doctype html>\n<...    200.0  News
# 330  <!DOCTYPE html>\n<html lang="en-US" class="the...    200.0  News
# 331  <!DOCTYPE html><html lang="en" itemscope="" it...    200.0  News
# 332  \t\n    <!DOCTYPE html PUBLIC "-//W3C//DTD XHT...    200.0  News
# 333  <!DOCTYPE html>\n<html xmlns="http://www.w3.or...    200.0  News
# 334  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa ...    200.0  News
# 336  <!doctype html><html lang="en" dir="ltr" class...    200.0  News
# 337  <!doctype html>\n<!--\n://////////////////////...    200.0  News
# 338  <!doctype html>\n<html data-reactroot=""><head...    200.0  News
# 339  <!DOCTYPE html><html dir="ltr" lang="en-US" cl...    200.0  News
# 340  <!DOCTYPE HTML><html lang="en"><head><meta htt...    200.0  News
# 341  <!DOCTYPE html>\n<html lang="en">\n<head>\n<ti...    200.0  News
# 342  <!DOCTYPE html>\n<html class="njs ">\n<head>\n...    200.0  News
# 343  <!DOCTYPE html>\n<html lang="fa" dir="rtl" xml...    200.0  News
# 344  <!doctype html>\n<html class="no-js" lang="en"...    200.0  News
# 345  \r\n\r\n<!DOCTYPE html>\r\n<html class="yr" la...    200.0  News
# 346  <!DOCTYPE html><html lang="en" dir="ltr" class...    200.0  News
# 347  <!DOCTYPE html>\n<!--[if IE 6]>\n<html id="ie6...    200.0  News
# 348  <!DOCTYPE html><html class="no-js" lang="en"><...    200.0  News
#
#                                              meta_name  \
# 301  [description, keywords, lastmod, pubdate, refe...
# 302  [apple-itunes-app, apple-mobile-web-app-capabl...
# 303  [application-name, cg, description, keywords, ...
# 304  [description, google-site-verification, msappl...
# 305  [apple-itunes-app, description, google-site-ve...
# 306  [apple-mobile-web-app-title, application-name,...
# 307  [audio_url, description, external, keywords, m...
# 308  [apple-itunes-app, application-name, descripti...
# 309  [apple-itunes-app, apple-mobile-web-app-capabl...
# 310  [description, msapplication-tilecolor, msappli...
# 311  [description, google-site-verification, keywor...
# 312  [description, image, keywords, news_keywords, ...
# 313  [apple-itunes-app, description, keywords, news...
# 314  [description, google-site-verification, keywor...
# 315  [analyticsattributes.author, analyticsattribut...
# 316                                         [viewport]
# 318  [apple-itunes-app, description, handheldfriend...
# 319  [copyright, description, generator, google-sit...
# 322  [description, google-site-verification, msappl...
# 323  [ahrefs-site-verification, description, genera...
# 325  [apple-itunes-app, author, copyright, descript...
# 326  [description, google-site-verification, msappl...
# 327  [apple-itunes-app, apple-mobile-web-app-title,...
# 328                                                 []
# 329  [description, msapplication-tilecolor, msvalid...
# 330  [apple-mobile-web-app-capable, apple-mobile-we...
# 331     [description, keywords, theme-color, viewport]
# 332  [dc.contributor, dc.creator, dc.date.created, ...
# 333  [ahrefs-site-verification, apple-itunes-app, a...
# 334  [apple-itunes-app, dcterms.format, dcterms.ide...
# 336  [description, membershipdomain, og:description...
# 337  [description, news_keywords, pinterest:descrip...
# 338  [description, parsely-page, template, twitter:...
# 339  [apple-mobile-web-app-capable, apple-mobile-we...
# 340  [apple-itunes-app, description, google-site-ve...
# 341  [application-name, author, copyright, descript...
# 342  [apple-mobile-web-app-title, application-name,...
# 343  [copyright, date, dc.publisher, description, e...
# 344  [description, pagetype, robots, site, title, t...
# 345  [dcterms.creator, dcterms.datecopyrighted, dct...
# 346  [apple-itunes-app, apple-mobile-web-app-capabl...
# 347  [alexaverifyid, apple-itunes-app, apple-mobile...
# 348  [app-context, apple-itunes-app, apple-mobile-w...
#
#                                          meta_proprety  \
# 301  [fb:app_id, fb:pages, og:description, og:pubda...
# 302  [og:description, og:image, og:image:height, og...
# 303  [fb:app_id, og:description, og:image, og:title...
# 304  [fb:app_id, fb:pages, og:description, og:image...
# 305  [description, og:description, og:image, og:sit...
# 306  [al:ios:app_name, al:ios:app_store_id, al:ios:...
# 307  [fb:admins, fb:app_id, og:description, og:imag...
# 308  [fb:app_id, fb:pages, og:description, og:image...
# 309  [fb:pages, og:description, og:image, og:site_n...
# 310  [og:description, og:image, og:image:secure_url...
# 311  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 312  [article:publisher, fb:app_id, og:description,...
# 313  [al:ios:app_name, al:ios:app_store_id, article...
# 314  [al:android:app_name, al:android:package, al:a...
# 315  [fb:pages, og:description, og:image, og:locale...
# 316                                                 []
# 318                                     [og:site_name]
# 319  [article:content_tier, article:opinion, fb:pag...
# 322  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 323  [fb:pages, og:description, og:image, og:image:...
# 325  [fb:admins, fb:pages, og:description, og:site_...
# 326  [fb:app_id, fb:pages, og:description, og:image...
# 327                             [fb:admins, fb:app_id]
# 328                                                 []
# 329  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 330  [al:android:app_name, al:android:package, al:i...
# 331                                                 []
# 332                                                 []
# 333  [fb:app_id, fb:pages, og:description, og:image...
# 334  [fb:admins, fb:app_id, fb:pages, og:image, og:...
# 336                        [og:title, og:type, og:url]
# 337  [article:content_tier, article:opinion, fb:app...
# 338  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 339  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 340  [fb:admins, fb:app_id, fb:pages, og:descriptio...
# 341  [al:ipad:app_name, al:ipad:app_store_id, al:ip...
# 342                                                 []
# 343        [nastooh:pagetype, og:locale, og:site_name]
# 344                                                 []
# 345                           [fb:pages, og:site_name]
# 346  [fb:app_id, fb:pages, og:description, og:image...
# 347  [fb:admins, og:image, og:locale, og:site_name,...
# 348  [fb:pages, og:description, og:locale, og:local...
#
#                                                   desc  \
# 301  [Find the latest breaking news and information...
# 302  [Comprehensive up-to-date news coverage, aggre...
# 303  [Live news, investigations, opinion, photos an...
# 304  [Indiatimes, com brings you the news, articles...
# 305  [Download the best royalty free images from Sh...
# 306  [Latest international news, sport and comment ...
# 307  [Breaking news and analysis on politics, busin...
# 308  [The latest news and headlines from Yahoo! New...
# 309  [Breaking News, Latest News and Current News f...
# 310  [Wettervorhersage, Witterungsbedingungen und D...
# 311  [Top News in India: Read Latest News on Sports...
# 312  [Forbes is a global media company, focusing on...
# 313  [CNBC International is the world leader for ne...
# 314  [Business News- Read Latest Financial news, St...
# 315  [Reuters, com brings you the latest news from ...
# 316                                               None
# 318  [The Nation's Newspaper provides you with up-t...
# 319  [Your source for breaking news, news about New...
# 322  [Chron, com: Trending headlines, Houston cultu...
# 323  [India News, Latest News, Bihar Election 2020 ...
# 325  [News, off-beat stories and analysis of German...
# 326  [Go to NBCNews, com for breaking news, videos,...
# 327  [We say what people are thinking and cover the...
# 328                                               None
# 329  [SFGATE: Local news & information, updated wea...
# 330  [Watch CBSN the live news stream from CBS News...
# 331  [Weather Underground provides local & long-ran...
# 332                                               None
# 333  [Today's News Headlines, Breaking News & Lates...
# 334  [The Hill is a top US political website, read ...
# 336  [News, analysis from the Middle East & worldwi...
# 337  [Breaking news and analysis from TIME, com, Po...
# 338  [A smart, speedy take on the news from around ...
# 339  [The Atlantic covers news, politics, culture, ...
# 340  [Business News Today: Read Business News Headl...
# 341  [Your trusted source for breaking news, analys...
# 342  [Track news and sports headlines from the worl...
# 343  [آخرین اخبار  ایران و جهان را در خبرگزاری جمهو...
# 344  [Use Bankrate, com's free tools, expert analys...
# 345     [Værvarsel for 9,3 millioner steder i verden!]
# 346  [The best breaking news, stories, and events f...
# 347  [Entertainment news, film reviews, awards, fil...
# 348  [Latest breaking news available as free video ...
#
#                                               desc_emb  \
# 301  [0.05463076, -0.115279794, -0.021884818, 0.219...
# 302  [0.042763993, -0.15314756, 0.20327859, -0.0528...
# 303  [0.027615584, -0.09540923, 0.27004397, 0.09393...
# 304  [-0.015393503, 0.009364881, 0.223068, -0.17000...
# 305  [0.03366962, 0.3036318, 0.12352188, -0.2435743...
# 306  [-0.04433052, -0.19661677, 0.38723966, 0.01809...
# 307  [0.028368255, -0.0004745815, 0.20969395, 0.258...
# 308  [0.18077806, -0.21433915, 0.109997064, -0.0412...
# 309  [0.046627063, -0.13437973, 0.16410914, -0.0388...
# 310  [-0.03214953, 0.008435646, 0.09209535, -0.1385...
# 311  [0.0117045175, -0.07811718, 0.20779748, 0.0074...
# 312  [0.056074955, 0.16557848, 0.1771168, 0.0617334...
# 313  [0.10573589, 0.3570646, 0.17831172, -0.1047514...
# 314  [-0.0036711793, -0.09284371, 0.31588826, -0.08...
# 315  [0.1657504, -0.09241759, 0.39928594, -0.017600...
# 316                                               None
# 318  [0.028120432, 0.0074599613, 0.28449485, 0.0074...
# 319  [-0.03314526, 0.13825507, 0.39175192, 0.099918...
# 322  [-0.0047013587, -0.075392865, 0.2971597, -0.06...
# 323  [0.09087494, -0.035635084, 0.04447493, 0.16500...
# 325  [0.020356236, 0.14477743, 0.2542195, 0.3268718...
# 326  [0.08744846, 0.0034176218, 0.20164374, -0.0444...
# 327  [-0.07527047, 0.1408757, -0.17650606, -0.15514...
# 328                                               None
# 329  [0.100984186, -0.14013134, 0.2707124, 0.335740...
# 330  [0.24801384, 0.059079617, 0.18658802, 0.222275...
# 331  [0.13355745, 0.027151922, -0.110729136, 0.3470...
# 332                                               None
# 333  [0.2027293, 0.06409054, 0.18581451, 0.03111820...
# 334  [-0.07034949, 0.11408023, -0.018999279, -0.340...
# 336  [-0.0099162385, 0.11024601, 0.12075361, 0.2057...
# 337  [-0.00341174, -0.093765825, 0.23838116, -0.059...
# 338  [0.06271597, -0.19648422, 0.2993638, 0.0203026...
# 339  [0.07686265, 0.23966566, 0.12250371, 0.0942511...
# 340  [0.032074373, 0.07867563, 0.1437944, -0.073099...
# 341  [-0.07574494, 0.036792144, 0.08166299, -0.1871...
# 342  [0.0028551724, 0.03145858, 0.19697094, -0.0387...
# 343  [0.044668954, -0.013373368, 0.2640305, 0.26274...
# 344  [0.03485724, -0.03558183, 0.19273758, 0.294623...
# 345  [-0.014475679, -0.100703165, 0.29074714, -0.07...
# 346  [0.006197369, 0.012884093, 0.30938652, 0.29804...
# 347  [-0.026902221, 0.030908642, 0.17429432, -0.291...
# 348  [0.06894504, -0.10106502, 0.09597623, 0.059200...
#
#                                                     kw  \
# 301  [breaking news, news online, U.S. news, world ...
# 302                                               None
# 303  [news, live updates, latest news, breaking new...
# 304                                               None
# 305                                               None
# 306                                               None
# 307                                                 []
# 308                                               None
# 309  [news, breaking news, latest news, current new...
# 310                                               None
# 311  [News, Breaking news, Latest news, Live news, ...
# 312  [business, tech, leadership, entrepreneurs, in...
# 313           [CNBC Meets,Charting Asia,business news]
# 314  [business news, personal finance, nse, bse, fi...
# 315  [Breaking News,World News,Video news,Investing...
# 316                                               None
# 318                                               None
# 319                                               None
# 322                                               None
# 323  [latest news, breaking news, live news, live n...
# 325  [TOP STORIES, World News,german news,european ...
# 326                                               None
# 327  [News, Breaking News, Latest News, Australia N...
# 328                                               None
# 329                                               None
# 330  [CBS News, breaking news, national news, u.s. ...
# 331                                                 []
# 332                                               None
# 333                                               None
# 334  [The Hill, Capitol Hill, Newspaper, Dick Morri...
# 336                                               None
# 337                                               None
# 338                                               None
# 339                                               None
# 340  [share market news,Business news,mint,economy ...
# 341  [ABC News, breaking news, headline news, lates...
# 342  [news, NewsNow, Arsenal FC, Liverpool FC, Tott...
# 343  [Iran, IRNA, Middle East, Persian Gulf, World ...
# 344                                               None
# 345                                               None
# 346                                               None
# 347                                               None
# 348  [Latest news,  breaking news,  euronews,  euro...
#
#                                                 kw_emb
# 301  [0.07668236, 0.08707754, 0.07488214, 0.2393939...
# 302                                               None
# 303  [0.10261285, -0.081334464, 0.10582178, 0.18373...
# 304                                               None
# 305                                               None
# 306                                               None
# 307  [0.18770182, -0.31837517, 0.6503673, -0.046908...
# 308                                               None
# 309  [0.043595374, -0.0015108647, 0.20693666, 0.221...
# 310                                               None
# 311  [0.05586132, 0.014181809, 0.2073316, 0.0840158...
# 312  [-0.099655405, 0.1167268, 0.21893682, -0.13113...
# 313  [0.035126768, 0.0045008757, 0.0679413, -0.0086...
# 314  [-0.09369664, 0.08477868, 0.26187873, 0.200314...
# 315  [-0.02848502, 0.105352074, 0.16697814, 0.07276...
# 316                                               None
# 318                                               None
# 319                                               None
# 322                                               None
# 323  [0.07177022, -0.012554921, 0.1484916, -0.03936...
# 325  [0.21978912, 0.24850708, 0.18868269, 0.4350629...
# 326                                               None
# 327  [-0.2087949, -0.079451464, 0.11220583, -0.0760...
# 328                                               None
# 329                                               None
# 330  [0.08186947, 0.24560334, 0.111157775, 0.200902...
# 331  [0.18770182, -0.31837517, 0.6503673, -0.046908...
# 332                                               None
# 333                                               None
# 334  [-0.13913561, 0.22558814, 0.057638574, -0.4037...
# 336                                               None
# 337                                               None
# 338                                               None
# 339                                               None
# 340  [-0.116398536, 0.1443065, 0.16837522, 0.045255...
# 341  [-0.036102433, 0.15022595, -0.095695704, -0.02...
# 342  [0.031475734, 0.11730024, 0.029128574, -0.2063...
# 343  [-0.12860097, 0.20744716, 0.05747298, 0.447658...
# 344                                               None
# 345                                               None
# 346                                               None
# 347                                               None
# 348  [0.19299288, 0.07433598, 0.20755807, 0.2454232...
